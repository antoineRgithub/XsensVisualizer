# %%
import pandas as pd
import os

# %%
df = pd.read_csv(os.path.abspath('capteur.csv/'),index_col= 0).loc[:,'main-SampleTimeFine':'main-FreeAcc_Z'] # importe la base de données
main = df.dropna() # trie la base de données
main
# Out:
#                     main-SampleTimeFine  main-Quat_W  main-Quat_X    Quat_Y  \
# main-PacketCounter
# 1.0                         136916542.0     0.989972    -0.009425 -0.013887
# 2.0                         136933209.0     0.989972    -0.009415 -0.013885
# 3.0                         136949876.0     0.989972    -0.009421 -0.013872
# 4.0                         136966543.0     0.989974    -0.009426 -0.013875
# 5.0                         136983210.0     0.989974    -0.009435 -0.013879
# ...                                 ...          ...          ...       ...
# 2248.0                      174367291.0     0.974436    -0.010524 -0.014575
# 2249.0                      174383958.0     0.974437    -0.010517 -0.014571
# 2250.0                      174400625.0     0.974435    -0.010519 -0.014576
# 2251.0                      174417292.0     0.974433    -0.010513 -0.014583
# 2252.0                      174433959.0     0.974432    -0.010500 -0.014587
#
# ...
